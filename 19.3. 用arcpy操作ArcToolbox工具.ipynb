# %%
import sys
sys.version
# Out:
# '2.7.15 (v2.7.15:ca079a3ea3, Apr 30 2018, 16:22:17) [MSC v.1500 32 bit (Intel)]'

# %%
import arcpy

# %% [markdown]
# ### 1.工具入门

# %% [markdown]
# #### 1.1裁剪工具
# #### Syntax
# Clip_analysis (in_features, clip_features, out_feature_class, {cluster_tolerance})<br>
# + 前三个为必填参数

# %%
#设置工作空间
arcpy.env.workspace = r"D:\rui\code_analysis\homework\file\GIS\class1803.gdb"
arcpy.Clip_analysis("clip","clip2","clip_output")
print('done')

# %%
#绝对路径
arcpy.Clip_analysis(r"D:\rui\code_analysis\homework\file\GIS\class1803.gdb\clip",
                    r"D:\rui\code_analysis\homework\file\GIS\class1803.gdb\clip2",
                    r"D:\rui\code_analysis\homework\file\GIS\class1803.gdb\clip_output2")
print('done')
# Out:
# done

# %% [markdown]
# ### 2.如何使用arcpy工具

# %% [markdown]
# >arcpy.<工具名称>_<工具箱别名>

# %% [markdown]
# ### 3.如何使用自定义工具

# %% [markdown]
# #### 3.1右击工具箱设置别名

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3.2导入工具箱路径

# %%
arcpy.ImportToolbox(r"C:\Users\cc\Documents\ArcGIS\Toolbox.tbx","mytools")
# Out:
# <module 'mytools' (built-in)>

# %% [markdown]
# #### 3.3使用你的工具 arcpy.<工具名称>_mytools
