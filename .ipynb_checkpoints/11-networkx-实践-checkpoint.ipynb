# %%
import networkx as nx
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ## 初步创建图形

# %%
G= nx.Graph()

# %% [markdown]
# ### 1.添加节点与边

# %%
nodes = [1,2,3,4,5,6,7,8]
edges = [(1,2),(2,3),(2,8),(3,6),(3,7),(4,7),(5,7)]

# %%
G.add_nodes_from(nodes)

# %%
G.nodes(data=True)
# Out:
# NodeDataView({1: {}, 2: {}, 3: {}, 4: {}, 5: {}, 6: {}, 7: {}, 8: {}})

# %%
G.add_edges_from(edges)

# %%
G.edges(data=True)
# Out:
# EdgeDataView([(1, 2, {}), (2, 3, {}), (2, 8, {}), (3, 6, {}), (3, 7, {}), (4, 7, {}), (5, 7, {})])

# %% [markdown]
# ### 2.图形初步显示

# %% [markdown]
# https://networkx.github.io/documentation/stable/reference/drawing.html

# %%
nx.draw(G,with_labels=True)
plt.show()
# Out:
# C:\Users\workload\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# ### 定义pos，每个节点的位置不变

# %%
pos = nx.spring_layout(G)

# %%
nx.draw(G,pos=pos, with_labels=True)

# %%
nx.draw_networkx(G,pos=pos, with_labels=True)

# %%
nx.draw(G,pos=pos, with_labels=True, width=0, node_size=0)
nx.draw_networkx_nodes(G, pos=pos, 
                       node_list=[1,2,3,4,5,6,7,8], 
                       node_size=[100,200,300,400,500,600,700,800], 
                      node_color=G.nodes())
nx.draw_networkx_edges(G, pos=pos, 
                       edge_list=[1,2,3,4,5,6,7,8], 
                       width=[4,6,8,12,19,20,26,44],alpha=0.5)

# %% [markdown]
# ### 思考？如果节点的位置（pos）就是经纬度坐标，就可以进行实际的空间关联网络分析

# %%
pos
# Out:
# {1: array([-0.26457149,  0.90720535]),
#  2: array([0.03502426, 0.57994514]),
#  3: array([ 0.09364306, -0.01390583]),
#  4: array([-0.01391126, -1.        ]),
#  5: array([-0.51085882, -0.79355173]),
#  6: array([ 0.51986236, -0.07557285]),
#  7: array([-0.12942593, -0.56611336]),
#  8: array([0.27023782, 0.96199329])}

# %%
type(pos)
# Out:
# dict

# %% [markdown]
# ### 异常强大的算法

# %% [markdown]
# #### 平均最短路径长度
# https://networkx.github.io/documentation/stable/reference/algorithms/generated/networkx.algorithms.shortest_paths.generic.average_shortest_path_length.html?highlight=average_shortest_path_length#networkx.algorithms.shortest_paths.generic.average_shortest_path_length

# %%
nx.average_shortest_path_length(G)
# Out:
# 2.3214285714285716

# %% [markdown]
# https://networkx.github.io/documentation/stable/reference/generated/networkx.convert_matrix.from_pandas_edgelist.html?highlight=from_pandas_edgelist#networkx.convert_matrix.from_pandas_edgelist

# %%
# 获得需要去进行图形化的数据
import pandas as pd
city_net = pd.read_excel('./file/city_net/city_net.xlsx')
city_net.head(2)
# Out:
#    Unnamed: 0 SSGS_city ZGS_city  count
# 0        1136       北京市      深圳市    885
# 1         952       北京市      上海市    423

# %% [markdown]
# #### 特别注意 ：2.0以后版本，from_pandas_dataframe 改为  from_pandas_edgelist

# %%
# 数据转换为networkx图形对象
GA = nx.from_pandas_edgelist(city_net, source='SSGS_city', target='ZGS_city', edge_attr='count')

# %%
GA

# %%
# 读取城市的坐标
net_use = pd.read_csv('./data-use/coord.csv')
net_use = net_use[['city_01','lng_gis','lat_gis']]

# %%
# pandas对象转换为重点对象
dict_city = net_use.set_index('city_01').T.to_dict('list')
dict_city
# Out:
# C:\Users\workload\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning
#  '通化市': [1990573.0728554544, 4805054.455759428],
#  '石嘴山市': [371567.2872645464, 4320399.3618148435],
#  '邢台市': [1105431.855679482, 4141957.992370298],
#  '五家渠市': [-1129912.8702017479, 5121755.27555427],
#  '喀什地区': [-2233218.742598865, 4697800.969840414],
#  '宁波市': [1823163.6840908816, 3358657.2189282095],
#  '江门市': [982282.9764384708, 2460261.078089143],
#  '孝感市': [1061124.4288847344, 3458952.257283785],
#  '保定市': [1121375.668519238, 4345368.319548312],
#  '怒江傈僳族自治州': [-408612.1220697921, 3016343.144329209],
#  '双鸭山市': [2372718.7594216242, 5472703.238366388],
#  '岳阳市': [1012216.0465263751, 3227887.5862465543],
#  '安庆市': [1325705.8536258116, 3419367.0713823237],
#  '株洲市': [1047627.0548060528, 3012792.762448661],
#  '黑河市': [1879074.8813458262, 5634141.733424965],
#  '娄底市': [856582.7988225445, 3074749.008320237],
#  '抚州市': [1335098.6780650727, 3072446.4125771136],
#  '松原市': [1803325.0243748503, 5096694.073380755],
#  '五指山市': [658866.2051513164, 2083185.9921083727],
#  '长治市': [940894.2984696169, 4049506.507208848],
#  '南京市': [1528141.809160556, 3585416.8798302133],
#  '常德市': [842300.0845118058, 3247485.066358275],
#  '仙桃市': [1017540.9919592428, 3364572.7707821913],
#  '眉山市': [89437.5797336799, 3319595.0963800377],
#  '舟山市': [1878105.6710745248, 3444555.3867230564],
#  '云浮市': [889804.7656267781, 2529155.378556278],
#  '迪庆藏族自治州': [-344003.22006799397, 3123312.351922323],
#  '滁州市': [1451124.3621716762, 3647595.210983085],
#  '桂林市': [753085.1583838697, 2807525.6120243045],
#  '阿拉尔市': [-1771476.4148222278, 4856008.217134391],
#  '阿克苏地区': [-1737506.0582565325, 4888540.747976655],
#  '西双版纳傣族自治州': [-230281.8972439169, 2443067.813678255],
#  nan: [-82151.51069836787, 3895266.832628106]}

# %%
city_lst = []
for i in city_net['SSGS_city']:
    city_lst.append(i)
for i in city_net['ZGS_city']:
    city_lst.append(i)

dic = {}
nodelst = []
sizes = []
for i in city_lst:
    if city_lst.count(i)>0:
        dic[i] = city_lst.count(i)
for m,k in dic.items():
    nodelst.append(m)
    sizes.append(k)

    
fig, ax = plt.subplots(figsize=(18,18))
ax.set_title('中国城市网络空间联系结构',size=30)


country = gpd.GeoDataFrame.from_file('./shp/china.shp')
country = country.to_crs({'init':'epsg:2381'})
country.plot(ax=ax,color='#e2e2e2',alpha=0.5)
country02 = gpd.GeoDataFrame.from_file('./shp/china_arc2.shp')
country02 = country02.to_crs({'init':'epsg:2381'})
country02.plot(ax=ax,color='black',alpha=0.5)  
      
    
GA = nx.from_pandas_edgelist(city_net, source="SSGS_city", target="ZGS_city", edge_attr='count')
pos = dict_city


labels = {}    
for m,k in dic.items():
    if k > 300:
        labels[m] = m


edges = GA.edges() 

nx.draw(GA,pos, with_labels=False, alpha=0.1,
        nodelist = nodelst, node_size=sizes,font_family='SimHei')

nx.draw_networkx_labels(GA,pos,labels,
                        font_family='SimHei',font_size=15,font_color='black')

nx.draw_networkx_edges(GA, pos, width=0.5, alpha=0.1)


plt.show()
# plt.savefig('./jpg/networkx.png',dpi=300)
